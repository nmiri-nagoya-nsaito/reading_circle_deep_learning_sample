# %% [markdown]
# カレントディレクトリを確認（Jupyter Notebookでシェルコマンドを実行するには行頭に！を付加する）

# %%
# !pwd
# Out:
# /Users/saito/work/reading_circle_deep_learning_sample/framework_test

# %% [markdown]
# GitHubからソースコードをダウンロード

# %%
# !git clone https://github.com/chainer/chainer.git ../venv/chainer/chainer
# Out:
# Cloning into '../venv/chainer/chainer'...
# remote: Counting objects: 70263, done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 70263 (delta 1), reused 0 (delta 0), pack-reused 70261
# Receiving objects: 100% (70263/70263), 16.51 MiB | 6.12 MiB/s, done.
# Resolving deltas: 100% (49208/49208), done.
# Checking connectivity... done.

# %% [markdown]
# トレーニングのPythonスクリプトを実行

# %%
# !../venv/chainer/chainer/examples/mnist/train_mnist.py
# Out:
# GPU: -1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# ...
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     18.547 iters/sec. Estimated time to finish: 0:10:36.223783.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     18.737 iters/sec. Estimated time to finish: 0:10:24.440759.
#      total [#.................................................]  3.33%
# ...
